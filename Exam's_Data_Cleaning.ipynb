# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
data= pd.read_csv("Expanded_data_with_more_features.csv")

# %%
data.head(5)
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %% [markdown]
# # Deleting redundant columns

# %%
data
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
#        'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
#        'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
#        'ReadingScore', 'WritingScore'],
#       dtype='object')

# %%
data= data.drop(columns=['Unnamed: 0','TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild'])

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  NrSiblings  \
# 0      female         NaN   bachelor's degree      standard         3.0
# 1      female     group C        some college      standard         0.0
# 2      female     group B     master's degree      standard         4.0
# 3        male     group A  associate's degree  free/reduced         1.0
# 4        male     group C        some college      standard         0.0
# ...       ...         ...                 ...           ...         ...
# 30636  female     group D         high school      standard         2.0
# 30637    male     group E         high school      standard         1.0
# 30638  female         NaN         high school  free/reduced         1.0
# 30639  female     group D  associate's degree      standard         3.0
# 30640    male     group B        some college      standard         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %%
data.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %% [markdown]
# # Renaming the columns

# %%
data.head(5)
# Out:
#    Gender EthnicGroup          ParentEduc     LunchType  NrSiblings  \
# 0  female         NaN   bachelor's degree      standard         3.0
# 1  female     group C        some college      standard         0.0
# 2  female     group B     master's degree      standard         4.0
# 3    male     group A  associate's degree  free/reduced         1.0
# 4    male     group C        some college      standard         0.0
#
#   TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0     school_bus            < 5         71            71            74
# 1            NaN         5 - 10         69            90            88
# 2     school_bus            < 5         87            93            91
# 3            NaN         5 - 10         45            56            42
# 4     school_bus         5 - 10         76            78            75

# %%
data.rename(columns={"NrSiblings":"Numberof Siblings"}, inplace= True)

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  \
# 0      female         NaN   bachelor's degree      standard
# 1      female     group C        some college      standard
# 2      female     group B     master's degree      standard
# 3        male     group A  associate's degree  free/reduced
# 4        male     group C        some college      standard
# ...       ...         ...                 ...           ...
# 30636  female     group D         high school      standard
# 30637    male     group E         high school      standard
# 30638  female         NaN         high school  free/reduced
# 30639  female     group D  associate's degree      standard
# 30640    male     group B        some college      standard
#
#        Numberof Siblings TransportMeans WklyStudyHours  MathScore  \
# 0                    3.0     school_bus            < 5         71
# 1                    0.0            NaN         5 - 10         69
# ...

# %% [markdown]
# # Dropping Duplicates

# %%
data.duplicated().sum()
# Out:
# np.int64(9)

# %%
data.drop_duplicates(inplace= True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Removing null values

# %%
data.isnull().sum()
# Out:
# Gender                  0
# EthnicGroup          1840
# ParentEduc           1845
# LunchType               0
# Numberof Siblings    1571
# TransportMeans       3134
# WklyStudyHours        955
# MathScore               0
# ReadingScore            0
# WritingScore            0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# np.int64(9345)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Gender               0
# EthnicGroup          0
# ParentEduc           0
# LunchType            0
# Numberof Siblings    0
# TransportMeans       0
# WklyStudyHours       0
# MathScore            0
# ReadingScore         0
# WritingScore         0
# dtype: int64

# %% [markdown]
# # Some more Transformations

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  \
# 2      female     group B     master's degree      standard
# 4        male     group C        some college      standard
# 5      female     group B  associate's degree      standard
# 6      female     group B        some college      standard
# 7        male     group B        some college  free/reduced
# ...       ...         ...                 ...           ...
# 30634    male     group A  associate's degree  free/reduced
# 30635    male     group C        some college      standard
# 30636  female     group D         high school      standard
# 30637    male     group E         high school      standard
# 30639  female     group D  associate's degree      standard
#
#        Numberof Siblings TransportMeans WklyStudyHours  MathScore  \
# 2                    4.0     school_bus            < 5         87
# 4                    0.0     school_bus         5 - 10         76
# ...

# %%
data["Gender"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data["Gender"].nunique()
# Out:
# 2

# %%
data["Gender"]= data["Gender"].apply(lambda x:1 if x == "female" else 0)

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  \
# 2           1     group B     master's degree      standard
# 4           0     group C        some college      standard
# 5           1     group B  associate's degree      standard
# 6           1     group B        some college      standard
# 7           0     group B        some college  free/reduced
# ...       ...         ...                 ...           ...
# 30634       0     group A  associate's degree  free/reduced
# 30635       0     group C        some college      standard
# 30636       1     group D         high school      standard
# 30637       0     group E         high school      standard
# 30639       1     group D  associate's degree      standard
#
#        Numberof Siblings TransportMeans WklyStudyHours  MathScore  \
# 2                    4.0     school_bus            < 5         87
# 4                    0.0     school_bus         5 - 10         76
# ...

# %%
data= data.reset_index()

# %%
data
# Out:
#        index  Gender EthnicGroup          ParentEduc     LunchType  \
# 0          2       1     group B     master's degree      standard
# 1          4       0     group C        some college      standard
# 2          5       1     group B  associate's degree      standard
# 3          6       1     group B        some college      standard
# 4          7       0     group B        some college  free/reduced
# ...      ...     ...         ...                 ...           ...
# 22338  30634       0     group A  associate's degree  free/reduced
# 22339  30635       0     group C        some college      standard
# 22340  30636       1     group D         high school      standard
# 22341  30637       0     group E         high school      standard
# 22342  30639       1     group D  associate's degree      standard
#
#        Numberof Siblings TransportMeans WklyStudyHours  MathScore  \
# 0                    4.0     school_bus            < 5         87
# ...

# %%
data.drop(columns="index", inplace= True)

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  \
# 0           1     group B     master's degree      standard
# 1           0     group C        some college      standard
# 2           1     group B  associate's degree      standard
# 3           1     group B        some college      standard
# 4           0     group B        some college  free/reduced
# ...       ...         ...                 ...           ...
# 22338       0     group A  associate's degree  free/reduced
# 22339       0     group C        some college      standard
# 22340       1     group D         high school      standard
# 22341       0     group E         high school      standard
# 22342       1     group D  associate's degree      standard
#
#        Numberof Siblings TransportMeans WklyStudyHours  MathScore  \
# 0                    4.0     school_bus            < 5         87
# 1                    0.0     school_bus         5 - 10         76
# ...

# %%
type(data["Numberof Siblings"][3])
# Out:
# numpy.float64

# %%
data["Numberof Siblings"]= data["Numberof Siblings"].astype(int)

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  \
# 0           1     group B     master's degree      standard
# 1           0     group C        some college      standard
# 2           1     group B  associate's degree      standard
# 3           1     group B        some college      standard
# 4           0     group B        some college  free/reduced
# ...       ...         ...                 ...           ...
# 22338       0     group A  associate's degree  free/reduced
# 22339       0     group C        some college      standard
# 22340       1     group D         high school      standard
# 22341       0     group E         high school      standard
# 22342       1     group D  associate's degree      standard
#
#        Numberof Siblings TransportMeans WklyStudyHours  MathScore  \
# 0                      4     school_bus            < 5         87
# 1                      0     school_bus         5 - 10         76
# ...

# %%
data.to_excel("Cleaned_data.xlsx")

# %%
data.to_csv("Cleaned_data.csv")
